# %%
import requests
page = requests.get("https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD%EC%9D%98_%EC%98%81%ED%99%94_%ED%9D%A5%ED%96%89_%EA%B8%B0%EB%A1%9D")

from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

table = html.find_all('table')

#print(table[0])

#td = table[0].find_all('td')

#title = []
#for i in range(len(td)):
#    if i % 7 == 1:
#       title.append(td[i].get_text())
       
#print(title)    
Col1 = []

Col3 = []


trow2 = table[1].find_all('tr')
for row in trow2:
     cell = row.find_all('td')
#     print(len(cell))
     if len(cell) == 5:
         Col1.append(cell[0].get_text())
         
         Col3.append(cell[2].get_text())
         
     elif len(cell) == 4:
         
         Col3.append(cell[1].get_text())
         
         
print ('\n'.join(Col3).strip())
# Out:
# 《007 위기일발》
#
# 《별들의 고향》
#
# 《겨울여자》
#
# 《취권》
#
# 《깊고 푸른 밤》
#
# 《킬링필드》
#
# 《창공을 날아라》
#
# 《나이아가라》
#
# 《장군의 아들》
#
# 《서편제》
#
# 《타이타닉》
#
# 《쉬리》
#
# 《친구》
#
# 《실미도》
#
# 《태극기 휘날리며》
#
# 《왕의 남자》
#
# 《괴물》
#
# 《해운대》
#
# 《아바타》
#
# 《도둑들》
#
# 《광해 왕이 된 남자》
#
# 《7번방의 선물》
#
# 《변호인》
#
# 《겨울왕국》
#
# 《명량》
#
# 《인터스텔라》
#
# 《국제시장》
#
# 《어벤져스: 에이지 오브 울트론》
#
# 《암살》
#
# 《베테랑》
#
# 《부산행》
#
# 《택시운전사》
#
# 《신과함께: 죄와 벌》
#
# 《어벤져스: 인피니티 워》
#
# 《신과함께: 인과 연》
#
# 《극한직업》
#
# 《어벤져스: 엔드게임》

# %%
import pandas as pd
df=pd.DataFrame(A,columns=['Number'])
df['State/UT']=B
df['Admin_Capital']=C
df['Legislative_Capital']=D
df['Judiciary_Capital']=E
df['Year_Capital']=F
df['Former_Capital']=G
